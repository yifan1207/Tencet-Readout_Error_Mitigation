# %%
import tensorcircuit as tc
from tensorcircuit.cloud import apis
from tensorcircuit.noisemodel import NoiseConf
from tensorcircuit.noisemodel import circuit_with_noise
import numpy as np
from scipy.optimize import minimize
from tensorcircuit.cloud import apis
import mthree
apis.set_token("6quf-SXbMHtzHP-bgKYoOEbWGRMFF-TAe4SmExzn4k2zWaaNBFkyuBMLujreoZwdKO4wFWM9EnokXHl-6XIMZHxMODxOt0qNle4QCYerwkuMc358qANAX-A9OUbyDqbV.N4XbhoDOtkhDGbB6UhXHyaa")

n = 13
shots = 10000
online_mode = 0
np.set_printoptions(suppress=True, precision=6)

def get_A(l, r):

    A = np.zeros((2 ** (r - l), 2 ** (r - l)))

    for i in range(0, (2 ** (r - l))) :

        circ = tc.Circuit(n)

        for j in range(0, r - l):
            if ((i & (2 ** j)) != 0) :
                circ.x(r - 1 - j)

        if online_mode == 1:
            t = apis.submit_task(provider="tencent", device="tianji_s2", circuit=circ, shots=shots)
            res = t.results()
        else :
            res = circ.sample(shots, format = "count_dict_bin", readout_error=readout_error, allow_state=True) 

        for str,c in res.items():
            A[int(str[l : r], 2)][i] += c / shots

    return A

def get_readout_error(n):
    base_error = [0.95, 0.9]
    readout_error = []

    for j in range(n):
        random_change_0 = 0.01 * np.random.rand()
        random_change_1 = 0.01 * np.random.rand()
        readout_error.append([base_error[0] - random_change_0, base_error[1] - random_change_1])

    return readout_error 

readout_error = get_readout_error(n)

A_plus = np.ones((1, 1))
A_plus = np.kron(A_plus, np.linalg.pinv(get_A(0, min(4, n))))
if n > 4 :
    A_plus = np.kron(A_plus, np.linalg.pinv(get_A(4, min(8, n))))
if n > 8 :
    A_plus = np.kron(A_plus, np.linalg.pinv(get_A(8, n)))
# A_plus = np.kron(A_plus, np.linalg.pinv(get_A(0, 9)))
# A_plus = np.kron(A_plus, np.linalg.pinv(get_A(0, 2)))

check_circ = tc.Circuit(n)
check_circ.h(1)
check_circ.h(3)
check_circ.x(4)
check_circ.cz(1,3)
check_circ.cx(3,5)
check_circ.h(8)
print(check_circ.draw())

# res = check_circ.sample(shots, format = "count_dict_bin", allow_state=True)
# real_x = np.zeros(2 ** n)
# for str,c in res.items():
#     real_x[int(str, 2)] = c / shots
# print(real_x)

if online_mode == 1 :
    t = apis.submit_task(provider="tencent", device="tianji_s2", circuit=check_circ, shots=shots)
    res = t.results()
else :
    res = check_circ.sample(shots, format = "count_dict_bin", readout_error=readout_error, allow_state=True)
y = np.zeros(2 ** n)
for str,c in res.items():
    y[int(str, 2)] = c

x = A_plus @ y
print(x)

def vector_to_dict(vector):
    n = len(vector)
    num_bits = len(bin(n - 1)) - 2

    result_dict = {}
    for i in range(n):
        binary_key = format(i, f'0{num_bits}b')
        result_dict[binary_key] = vector[i]

    return result_dict

print(mthree.classes.QuasiDistribution(vector_to_dict(x)).nearest_probability_distribution())
# Out:
#
#  q_0: ─────────────
#       ┌───┐
#  q_1: ┤ H ├─■──────
#       └───┘ │
#  q_2: ──────┼──────
#       ┌───┐ │
#  q_3: ┤ H ├─■───■──
#       ├───┤     │
#  q_4: ┤ X ├─────┼──
#       └───┘   ┌─┴─┐
#  q_5: ────────┤ X ├
#               └───┘
#  q_6: ─────────────
#
#  q_7: ─────────────
#       ┌───┐
#  q_8: ┤ H ├────────
#       └───┘
#  q_9: ─────────────
#
# q_10: ─────────────
#
# q_11: ─────────────
#
# q_12: ─────────────
#
# [ 4.674799 -1.21273   6.361091 ... -0.001409 -0.001321  0.000053]
# {'1100101000000': 1.7264240299870367e-05, '0100100100000': 0.00015819903765642166, '0001010000001': 0.0001820945181272738, '0101110100000': 0.00025583046325442584, '0100110010100': 0.0002717708102468754, '0001110100000': 0.00032728587893593426, '0100000010000': 0.0003987281643535141, '0100100000001': 0.00043550993266190424, '1001110000000': 0.00044590422994393244, '0100000000000': 0.0006356755617020536, '0001110010010': 0.0006423937502946008, '0100100000010': 0.0006544759716568398, '0100100001000': 0.0006823881191563526, '0011110010000': 0.000691085219138936, '0001110110000': 0.0006963849829170591, '0101111000000': 0.0008209617634942664, '0000000010000': 0.0010237270739437128, '0001110001000': 0.0013302813346783371, '0100110000000': 0.0013341917497624047, '0000110010000': 0.0013842895563909445, '0001110000010': 0.001427674926474665, '0101100010000': 0.0014879302044138634, '0101110110000': 0.0016393808992709203, '0100110010000': 0.0017766607045572379, '0100100011000': 0.0026941006159990374, '0100100000000': 0.11842417649129833, '0101110010000': 0.12060334789913345, '0001110000000': 0.12123137868983161, '0100100010000': 0.12173978101551752, '0101110000000': 0.12258209934132477, '0000100010000': 0.12259672443678668, '0000100000000': 0.12455066593386523, '0001110010000': 0.12685763648291104}

# %%
pip install wheel
# Out:
# Requirement already satisfied: wheel in /home/tencent_go/anaconda3/lib/python3.11/site-packages (0.41.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install twine
# Out:
# Collecting twine
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pkginfo>=1.8.1 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (1.9.6)
# Collecting readme-renderer>=35.0 (from twine)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (2.31.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (23.13.1)
# Collecting rfc3986>=1.4.0 (from twine)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from twine) (13.3.5)
# Requirement already satisfied: zipp>=0.5 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=3.6->twine) (3.17.0)
# Requirement already satisfied: jaraco.classes in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from keyring>=15.1->twine) (3.2.1)
# Requirement already satisfied: SecretStorage>=3.2 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from keyring>=15.1->twine) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from keyring>=15.1->twine) (0.7.1)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine)
#   Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from readme-renderer>=35.0->twine) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from requests>=2.20->twine) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from requests>=2.20->twine) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from requests>=2.20->twine) (2024.7.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from rich>=12.0.0->twine) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine) (0.1.0)
# Requirement already satisfied: cryptography>=2.0 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from SecretStorage>=3.2->keyring>=15.1->twine) (42.0.2)
# Requirement already satisfied: more-itertools in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from jaraco.classes->keyring>=15.1->twine) (10.1.0)
# Requirement already satisfied: cffi>=1.12 in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine) (1.16.0)
# Requirement already satisfied: pycparser in /home/tencent_go/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine) (2.21)
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 24.2 MB/s eta 0:00:00
# Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.2/769.2 kB 11.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: nh3, rfc3986, docutils, readme-renderer, twine
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 5.0.2 requires docutils<0.19,>=0.14, but you have docutils 0.21.2 which is incompatible.
# Successfully installed docutils-0.21.2 nh3-0.2.18 readme-renderer-44.0 rfc3986-2.0.0 twine-5.1.1
# Note: you may need to restart the kernel to use updated packages.
