# %% [markdown]
# # Problem 6
#
# 更大规模的电路, 尝试去除噪声. 什么方法都可以, ZNE 也可以

# %%
import tensorcircuit as tc
from tensorcircuit.cloud import apis
from tensorcircuit.noisemodel import NoiseConf
from tensorcircuit.noisemodel import circuit_with_noise
import numpy as np


# Requirement: The error mitigation results should be as close as possible to the noiseless results while using as few shots as possible.
qubit_num = 4
depth_num = 3
global sample_total
sample_total = 0
sim_backend = "expect" # OR "sample"
# In the example, we use a density matrix simulator to directly calculate the exact value of the observable's expectation. 
# However, on a real quantum computer, we can only obtain results from probability sampling. 
# Therefore, if we want to simulate a real quantum computer as closely as possible, sim_backend be set to "sample" here, 


# In this task, you can only use the following function to simulate circuit sampling. This simulator will automatically add noise.
def sampling_circuit(circ,sample_num = 10000,scale_factor = 1):

    if scale_factor <= 0.99:
        print("scale factor is too small! We will set scale factor to 1")
        scale_factor = 1

    if 0.01*scale_factor/8 >= 1/16:
        print("error rate is too high! We will set scale factor to 50")
        scale_factor = 50


    global sample_total
    sample_total += sample_num


    noise_conf = NoiseConf()
    error1 = tc.channels.generaldepolarizingchannel(0.01*scale_factor/8, 2)
    noise_conf.add_noise("cz", error1) # Rule for adding noise: Add a noise channel like error1 after each CZ gate
    
    circ2 = circuit_with_noise(circ, noise_conf)
    if sim_backend == "sample":
        return circ2.sample(sample_num,format = "count_dict_bin",staticmethod = True)
    else:
        return np.real(circ2.expectation_ps(z=[0]))



    

def count_dict_bin2expect(result0):
    if sim_backend == "sample":
        S = 0
        shot_num = 0
        for value in result0.values():
            shot_num += value

        for key in result0:
            if key[0] == '0':
                S += result0[key]
            else:
                S -= result0[key]
        S = S/shot_num
        return S
    else:
        return np.real(result0)


    



# circuit example
def QGAN_circuit(params,depth_num = 2):
    # depth_num indicates the number of repetitions of the basic layer in this circuit
    # Each basic layer contains an RY operation on each qubit and an entanglement layer composed of CZ gates

    circ = tc.DMCircuit(qubit_num)
    for index in range(0,depth_num):
        for jndex in range(qubit_num):

            circ.ry(jndex, theta=params[index*qubit_num+jndex])
            
        for jndex in range(qubit_num-1):
            circ.cz(jndex,jndex+1)

        
    
    return circ

param0 = np.random.rand(qubit_num*depth_num)*2*np.pi
circ = QGAN_circuit(param0,depth_num =depth_num)
print(circ.draw())

# Please provide a mitigation plan. The following example is a polynomial fitting ZNE protocol.

def ZNE_Poly_protocol(circ):
    f_value = []
    scale_factor_list = [1,1.01,1.02,1.03]
    for scale_factor in scale_factor_list:
        f_value.append(count_dict_bin2expect(sampling_circuit(circ,scale_factor = scale_factor)))
        # f_value.append(sampling_circuit(circ,scale_factor = scale_factor))

    degree = 1
    print("f_value",f_value)
    coefficients = np.polyfit(np.array(scale_factor_list), np.array(f_value), degree)
    
    # polynomial = np.poly1d(coefficients)
    return np.polyval(coefficients,0)



# benchmark
np.random.seed(2233)
sample_total = 0
N = 100
params_list = [np.random.rand(qubit_num*depth_num)*2*np.pi for index in range(N)]
QEM_val = []
noise_val = []
noise_free_val = []
for index in range(N):
    circ = QGAN_circuit(params_list[index],depth_num =depth_num)
    QEM_val.append(ZNE_Poly_protocol(circ))
    noise_val.append(count_dict_bin2expect(sampling_circuit(circ,scale_factor = 1)))
    # noise_val.append(sampling_circuit(circ,scale_factor = 1))
    noise_free_val.append(circ.expectation_ps(z=[0]))
    print(QEM_val[-1])
    print(noise_val[-1])
    print(noise_free_val[-1])
    # print(ZNE_Poly_protocol(circ))
    # print(circ.expectation_ps(z=[0]))
    # print(count_dict_bin2expect(circ.sample(1000,format = "count_dict_bin")))
# Out:
# 2024-07-27 21:08:51.294797: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-27 21:08:52.124993: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-27 21:08:52.125155: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-27 21:08:52.267803: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-27 21:08:52.575239: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-27 21:08:52.579450: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-27 21:08:56.325117: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Please first ``pip install -U cirq`` to enable related functionality in translation module
#       ┌────────────┐   ┌────────────┐                           ┌─────────────┐»
# q_0: ─┤ Ry(2.2233) ├─■─┤ Ry(2.2094) ├───────────────────■───────┤ Ry(0.51031) ├»
#       ├────────────┤ │ └────────────┘┌───────────┐      │       └─────────────┘»
# q_1: ─┤ Ry(4.0135) ├─■───────■───────┤ Ry(5.822) ├──────■──────────────■───────»
#       ├────────────┤         │       └───────────┘┌────────────┐       │       »
# q_2: ─┤ Ry(4.8607) ├─────────■─────────────■──────┤ Ry(3.0842) ├───────■───────»
#      ┌┴────────────┤                       │      ├────────────┤               »
# q_3: ┤ Ry(0.79372) ├───────────────────────■──────┤ Ry(4.9769) ├───────────────»
#      └─────────────┘                              └────────────┘               »
# «
# «q_0: ───────────────────■─────────────
# «     ┌───────────┐      │
# «q_1: ┤ Ry(3.828) ├──────■────────■────
# «     └───────────┘┌────────────┐ │
# «q_2: ──────■──────┤ Ry(1.6214) ├─■──■─
# «           │      ├────────────┤    │
# «q_3: ──────■──────┤ Ry(2.6254) ├────■─
# «                  └────────────┘
# f_value [array(-0.527733, dtype=float32), array(-0.5273887, dtype=float32), array(-0.5270456, dtype=float32), array(-0.5267017, dtype=float32)]
# -0.5621038377284884
# -0.527733
# (-0.56292284+0j)
# f_value [array(0.23098561, dtype=float32), array(0.23085558, dtype=float32), array(0.230726, dtype=float32), array(0.23059624, dtype=float32)]
# 0.24396233856677585
# 0.23098555
# (0.24418458+0j)
# f_value [array(-0.3572706, dtype=float32), array(-0.3570975, dtype=float32), array(-0.35692596, dtype=float32), array(-0.35675347, dtype=float32)]
# -0.3744996428489664
# -0.35727066
# (-0.37465835+0j)
# f_value [array(0.41516155, dtype=float32), array(0.41490835, dtype=float32), array(0.4146565, dtype=float32), array(0.414404, dtype=float32)]
# 0.4404062241315764
# 0.4151617
# (0.44094133+0j)
# f_value [array(0.08945018, dtype=float32), array(0.08941153, dtype=float32), array(0.08937317, dtype=float32), array(0.08933455, dtype=float32)]
# 0.09330269098281778
# 0.08945024
# (0.09331632+0j)
# f_value [array(0.3486309, dtype=float32), array(0.3483832, dtype=float32), array(0.34813648, dtype=float32), array(0.34788945, dtype=float32)]
# 0.37334126234054155
# 0.34863088
# (0.3740085+0j)
# f_value [array(0.00346908, dtype=float32), array(0.00347295, dtype=float32), array(0.00347692, dtype=float32), array(0.00348073, dtype=float32)]
# 0.0030798643827438447
# 0.0034691095
# (0.0030443072+0j)
# f_value [array(-0.26342586, dtype=float32), array(-0.26323098, dtype=float32), array(-0.26303643, dtype=float32), array(-0.26284188, dtype=float32)]
# -0.28289054930209967
# -0.2634259
# (-0.2834464+0j)
# f_value [array(0.6794023, dtype=float32), array(0.6788665, dtype=float32), array(0.6783322, dtype=float32), array(0.6777972, dtype=float32)]
# 0.7328977525234159
# 0.6794023
# (0.73454994+0j)
# f_value [array(-0.24249932, dtype=float32), array(-0.2423138, dtype=float32), array(-0.24212876, dtype=float32), array(-0.2419436, dtype=float32)]
# -0.2610213458538016
# -0.24249938
# (-0.26157564+0j)
# f_value [array(0.41733965, dtype=float32), array(0.41703683, dtype=float32), array(0.4167351, dtype=float32), array(0.41643274, dtype=float32)]
# 0.44756407439708634
# 0.4173396
# (0.44841713+0j)
# f_value [array(-0.08354023, dtype=float32), array(-0.08356011, dtype=float32), array(-0.0835802, dtype=float32), array(-0.0836001, dtype=float32)]
# -0.081543150544166
# -0.08354023
# (-0.08119652+0j)
# f_value [array(-0.19173548, dtype=float32), array(-0.19165176, dtype=float32), array(-0.19156867, dtype=float32), array(-0.19148543, dtype=float32)]
# -0.20006745159625788
# -0.19173548
# (-0.20010439+0j)
# f_value [array(0.67754495, dtype=float32), array(0.67713034, dtype=float32), array(0.67671835, dtype=float32), array(0.67630506, dtype=float32)]
# 0.7188611745834265
# 0.6775449
# (0.71973616+0j)
# f_value [array(0.5215385, dtype=float32), array(0.5212474, dtype=float32), array(0.5209581, dtype=float32), array(0.5206681, dtype=float32)]
# 0.5505429089069312
# 0.5215385
# (0.55103904+0j)
# f_value [array(-0.6159651, dtype=float32), array(-0.6155633, dtype=float32), array(-0.61516285, dtype=float32), array(-0.61476165, dtype=float32)]
# -0.6560734152793849
# -0.6159651
# (-0.65703505+0j)
# f_value [array(0.30471307, dtype=float32), array(0.30451003, dtype=float32), array(0.3043081, dtype=float32), array(0.30410564, dtype=float32)]
# 0.32495517432689563
# 0.30471307
# (0.32545486+0j)
# f_value [array(0.73151594, dtype=float32), array(0.7310773, dtype=float32), array(0.730641, dtype=float32), array(0.7302034, dtype=float32)]
# 0.7752551853656656
# 0.73151594
# (0.7761439+0j)
# f_value [array(-0.684484, dtype=float32), array(-0.6840329, dtype=float32), array(-0.6835841, dtype=float32), array(-0.6831341, dtype=float32)]
# -0.7294695734977632
# -0.684484
# (-0.7305576+0j)
# f_value [array(0.46285537, dtype=float32), array(0.46259362, dtype=float32), array(0.4623332, dtype=float32), array(0.46207204, dtype=float32)]
# 0.48895896971225444
# 0.46285537
# (0.48942006+0j)
# f_value [array(0.1211175, dtype=float32), array(0.12105098, dtype=float32), array(0.12098488, dtype=float32), array(0.12091875, dtype=float32)]
# 0.12774094939231695
# 0.1211175
# (0.12785327+0j)
# f_value [array(0.83669025, dtype=float32), array(0.8361607, dtype=float32), array(0.8356341, dtype=float32), array(0.83510596, dtype=float32)]
# 0.8894844949245319
# 0.83669025
# (0.8906791+0j)
# f_value [array(0.5405726, dtype=float32), array(0.5402685, dtype=float32), array(0.53996605, dtype=float32), array(0.5396625, dtype=float32)]
# 0.5708997488021764
# 0.54057264
# (0.57142645+0j)
# f_value [array(0.41761976, dtype=float32), array(0.41729292, dtype=float32), array(0.41696775, dtype=float32), array(0.41664156, dtype=float32)]
# 0.4502172470092695
# 0.41761976
# (0.4512105+0j)
# f_value [array(-0.8030637, dtype=float32), array(-0.8025625, dtype=float32), array(-0.8020636, dtype=float32), array(-0.8015636, dtype=float32)]
# -0.8530542194843254
# -0.8030637
# (-0.8541615+0j)
# f_value [array(-0.48260003, dtype=float32), array(-0.48224047, dtype=float32), array(-0.48188198, dtype=float32), array(-0.4815229, dtype=float32)]
# -0.5184991121292087
# -0.48260003
# (-0.51954025+0j)
# f_value [array(0.38117936, dtype=float32), array(0.38086814, dtype=float32), array(0.38055772, dtype=float32), array(0.38024718, dtype=float32)]
# 0.41224896013736323
# 0.3811794
# (0.41324958+0j)
# f_value [array(-0.5452684, dtype=float32), array(-0.5448191, dtype=float32), array(-0.5443715, dtype=float32), array(-0.543923, dtype=float32)]
# -0.590106272697444
# -0.5452685
# (-0.591557+0j)
# f_value [array(-0.48847193, dtype=float32), array(-0.48809725, dtype=float32), array(-0.487724, dtype=float32), array(-0.48735029, dtype=float32)]
# -0.5258532404899521
# -0.48847187
# (-0.5269783+0j)
# f_value [array(-0.6769716, dtype=float32), array(-0.6765456, dtype=float32), array(-0.6761217, dtype=float32), array(-0.67569685, dtype=float32)]
# -0.7194531977176649
# -0.6769716
# (-0.7204011+0j)
# f_value [array(-0.8350596, dtype=float32), array(-0.83453983, dtype=float32), array(-0.834022, dtype=float32), array(-0.8335034, dtype=float32)]
# -0.8869223475456158
# -0.83505964
# (-0.88806856+0j)
# f_value [array(-0.8915294, dtype=float32), array(-0.89080155, dtype=float32), array(-0.8900761, dtype=float32), array(-0.88935, dtype=float32)]
# -0.9641648054122784
# -0.8915294
# (-0.9664881+0j)
# f_value [array(-0.3037419, dtype=float32), array(-0.3035109, dtype=float32), array(-0.30328083, dtype=float32), array(-0.30305052, dtype=float32)]
# -0.32678393423556995
# -0.3037419
# (-0.32746744+0j)
# f_value [array(-0.7503204, dtype=float32), array(-0.7498522, dtype=float32), array(-0.74938625, dtype=float32), array(-0.7489191, dtype=float32)]
# -0.7970165967941188
# -0.7503204
# (-0.7980547+0j)
# f_value [array(0.15697622, dtype=float32), array(0.15685523, dtype=float32), array(0.1567348, dtype=float32), array(0.15661407, dtype=float32)]
# 0.1690451592206944
# 0.15697622
# (0.16941205+0j)
# f_value [array(0.69022256, dtype=float32), array(0.68979555, dtype=float32), array(0.68937075, dtype=float32), array(0.6889448, dtype=float32)]
# 0.7328024923801317
# 0.69022256
# (0.73372936+0j)
# f_value [array(-0.5566567, dtype=float32), array(-0.5563482, dtype=float32), array(-0.5560413, dtype=float32), array(-0.5557337, dtype=float32)]
# -0.5874165475368394
# -0.5566567
# (-0.5879327+0j)
# f_value [array(-0.54429907, dtype=float32), array(-0.54397696, dtype=float32), array(-0.5436563, dtype=float32), array(-0.5433351, dtype=float32)]
# -0.5764250516891449
# -0.54429907
# (-0.57706416+0j)
# f_value [array(0.49460423, dtype=float32), array(0.49421725, dtype=float32), array(0.49383163, dtype=float32), array(0.49344563, dtype=float32)]
# 0.5332178711891127
# 0.49460423
# (0.5344015+0j)
# f_value [array(-0.10745236, dtype=float32), array(-0.10736957, dtype=float32), array(-0.1072872, dtype=float32), array(-0.10720453, dtype=float32)]
# -0.11571111679076977
# -0.10745236
# (-0.11596322+0j)
# f_value [array(-0.51911795, dtype=float32), array(-0.5188041, dtype=float32), array(-0.51849186, dtype=float32), array(-0.5181787, dtype=float32)]
# -0.5504172325134252
# -0.51911795
# (-0.55106026+0j)
# f_value [array(0.5624069, dtype=float32), array(0.56191355, dtype=float32), array(0.5614216, dtype=float32), array(0.5609293, dtype=float32)]
# 0.6116542875766701
# 0.5624069
# (0.6133384+0j)
# f_value [array(-0.7310915, dtype=float32), array(-0.73051965, dtype=float32), array(-0.7299502, dtype=float32), array(-0.7293803, dtype=float32)]
# -0.7881211876869165
# -0.7310915
# (-0.78986555+0j)
# f_value [array(0.70848477, dtype=float32), array(0.7080687, dtype=float32), array(0.7076549, dtype=float32), array(0.7072398, dtype=float32)]
# 0.7499715745449019
# 0.70848477
# (0.7507703+0j)
# f_value [array(0.1063664, dtype=float32), array(0.10627335, dtype=float32), array(0.10618064, dtype=float32), array(0.1060878, dtype=float32)]
# 0.11565123498439675
# 0.106366396
# (0.11596885+0j)
# f_value [array(-0.6829969, dtype=float32), array(-0.6825561, dtype=float32), array(-0.6821172, dtype=float32), array(-0.6816775, dtype=float32)]
# -0.7269674479961271
# -0.682997
# (-0.72800726+0j)
# f_value [array(0.6663176, dtype=float32), array(0.66590154, dtype=float32), array(0.6654873, dtype=float32), array(0.66507226, dtype=float32)]
# 0.7078193187713632
# 0.6663176
# (0.7087362+0j)
# f_value [array(0.2366857, dtype=float32), array(0.2364954, dtype=float32), array(0.23630592, dtype=float32), array(0.23611617, dtype=float32)]
# 0.25566600859165123
# 0.2366857
# (0.2562639+0j)
# f_value [array(-0.57287914, dtype=float32), array(-0.5724125, dtype=float32), array(-0.5719471, dtype=float32), array(-0.5714814, dtype=float32)]
# -0.6194646179675986
# -0.5728792
# (-0.62095267+0j)
# f_value [array(0.09086576, dtype=float32), array(0.09074649, dtype=float32), array(0.09062761, dtype=float32), array(0.09050828, dtype=float32)]
# 0.10277891457080672
# 0.09086576
# (0.10330528+0j)
# f_value [array(0.09486806, dtype=float32), array(0.09473103, dtype=float32), array(0.09459457, dtype=float32), array(0.09445804, dtype=float32)]
# 0.10853316485881642
# 0.094868094
# (0.109163225+0j)
# f_value [array(0.41425636, dtype=float32), array(0.41391307, dtype=float32), array(0.41357124, dtype=float32), array(0.41322875, dtype=float32)]
# 0.4485027998685778
# 0.41425636
# (0.44962245+0j)
# f_value [array(0.6659127, dtype=float32), array(0.6655185, dtype=float32), array(0.6651263, dtype=float32), array(0.6647331, dtype=float32)]
# 0.7052215635776451
# 0.66591275
# (0.7060031+0j)
# f_value [array(0.5446318, dtype=float32), array(0.54416394, dtype=float32), array(0.54369724, dtype=float32), array(0.54322976, dtype=float32)]
# 0.5913592517375922
# 0.5446317
# (0.59292704+0j)
# f_value [array(-0.424765, dtype=float32), array(-0.42450225, dtype=float32), array(-0.42424104, dtype=float32), array(-0.4239791, dtype=float32)]
# -0.4509534686803737
# -0.42476508
# (-0.45153034+0j)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 121
#     119 for index in range(N):
#     120     circ = QGAN_circuit(params_list[index],depth_num =depth_num)
# --> 121     QEM_val.append(ZNE_Poly_protocol(circ))
#     122     noise_val.append(count_dict_bin2expect(sampling_circuit(circ,scale_factor = 1)))
#     123     # noise_val.append(sampling_circuit(circ,scale_factor = 1))
#
# Cell In[1], line 99, in ZNE_Poly_protocol(circ)
#      97 scale_factor_list = [1,1.01,1.02,1.03]
#      98 for scale_factor in scale_factor_list:
# ---> 99     f_value.append(count_dict_bin2expect(sampling_circuit(circ,scale_factor = scale_factor)))
#     100     # f_value.append(sampling_circuit(circ,scale_factor = scale_factor))
#     102 degree = 1
#
# Cell In[1], line 43, in sampling_circuit(circ, sample_num, scale_factor)
#      41     return circ2.sample(sample_num,format = "count_dict_bin",staticmethod = True)
#      42 else:
# ---> 43     return np.real(circ2.expectation_ps(z=[0]))
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/abstractcircuit.py:1270, in AbstractCircuit.expectation_ps(self, x, y, z, ps, reuse, noise_conf, nmc, status, **kws)
#    1268     for i in z:
#    1269         obs.append([gates.z(), [i]])  # type: ignore
# -> 1270 return self.expectation(
#    1271     *obs, reuse=reuse, noise_conf=noise_conf, nmc=nmc, status=status, **kws  # type: ignore
#    1272 )
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/densitymatrix.py:296, in DMCircuit.expectation(self, reuse, noise_conf, status, *ops, **kws)
#     293 from .noisemodel import expectation_noisfy
#     295 if noise_conf is None:
# --> 296     nodes = self.expectation_before(*ops, reuse=reuse)
#     297     return contractor(nodes).tensor
#     298 else:
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/basecircuit.py:282, in BaseCircuit.expectation_before(self, reuse, *ops, **kws)
#     280 nq = self._nqubits
#     281 if self.is_dm is True:
# --> 282     nodes, newdang = self._copy_state_tensor(reuse=reuse)
#     283 else:
#     284     nodes1, edge1 = self._copy_state_tensor(reuse=reuse)
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/basecircuit.py:253, in BaseCircuit._copy_state_tensor(self, conj, reuse)
#     251 if t is None:
#     252     nodes, d_edges = self._copy()
# --> 253     t = contractor(nodes, output_edge_order=d_edges)
#     254     setattr(self, "state_tensor", t)
#     255 ndict, edict = tn.copy([t], conjugate=conj)
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/cons.py:656, in custom(nodes, optimizer, memory_limit, output_edge_order, ignore_edge_order, **kws)
#     654     alg = optimizer
#     655 debug_level = kws.get("debug_level", 0)
# --> 656 return _base(
#     657     nodes,
#     658     alg,
#     659     output_edge_order,
#     660     ignore_edge_order,
#     661     total_size,
#     662     debug_level=debug_level,
#     663 )
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensorcircuit/cons.py:616, in _base(nodes, algorithm, output_edge_order, ignore_edge_order, total_size, debug_level)
#     614     new_node = pseudo_contract_between(nodes[a], nodes[b])
#     615 else:
# --> 616     new_node = tn.contract_between(nodes[a], nodes[b], allow_outer_product=True)
#     617 nodes.append(new_node)
#     618 # nodes[a] = backend.zeros([1])
#     619 # nodes[b] = backend.zeros([1])
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensornetwork/network_components.py:2232, in contract_between(node1, node2, name, allow_outer_product, output_edge_order, axis_names)
#    2230 axes1 = [axes1[i] for i in ind_sort]
#    2231 axes2 = [axes2[i] for i in ind_sort]
# -> 2232 new_tensor = backend.tensordot(node1.tensor, node2.tensor, [axes1, axes2])
#    2233 new_node = Node(tensor=new_tensor, name=name, backend=backend)
#    2234 # node1 and node2 get new edges in _remove_edges
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/tensornetwork/backends/numpy/numpy_backend.py:54, in NumPyBackend.tensordot(self, a, b, axes)
#      52         einsum_label = ",".join(["".join(labels_1), "".join(labels_2)])
#      53         return np.array(np.einsum(einsum_label, a, b, optimize=True))
# ---> 54     return np.tensordot(a, b, axes)
#      55 return np.tensordot(a, b, axes)
#
# File ~/anaconda3/envs/tc_with_tf/lib/python3.9/site-packages/numpy/core/numeric.py:1116, in tensordot(a, b, axes)
#    1114 for axis in axes_b:
#    1115     N2 *= bs[axis]
# -> 1116 newshape_b = (N2, int(multiply.reduce([bs[ax] for ax in notin])))
#    1117 oldb = [bs[axis] for axis in notin]
#    1119 at = a.transpose(newaxes_a).reshape(newshape_a)
#
# KeyboardInterrupt:

# %%
print("shot number: ",sample_total)
print("MSE of noise circuit: ",np.mean((np.array(noise_val)-np.array(noise_free_val))**2))
print("MSE of QEM circuit: ",np.mean((np.array(QEM_val)-np.array(noise_free_val))**2))
# Out:
# shot number:  5000000
# MSE of noise circuit:  (0.00136151+0j)
# MSE of QEM circuit:  (9.286824431856844e-07+0j)
